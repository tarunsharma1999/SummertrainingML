# %% [markdown]
# <a href="https://colab.research.google.com/github/tarunsharma1999/SummertrainingML/blob/master/StartingWithmatplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import time

# %%
x=[4,7,8,9,11,5]
y=[13,23,5,7,9,3]
player=['virat','dhoni','vijay','dhawna']
run=[120,44,77,33]

# %% [markdown]
# #Ploting Graph with grids

# %%
plt.xlabel('x-axis')
plt.ylabel('y-axis')

#minimum and maximum numbers in a axis
plt.xlim(0,12)
plt.ylim(0,24)

#plotting graph with "orange" label
plt.plot(x,y,label="orange")

plt.plot(x,y)
plt.grid(color='green')
plt.show()

# %% [markdown]
# #Ploting bar with grids

# %%
plt.bar(x,y,label='polution')
plt.bar(player,run,label='cricket')
plt.grid(color='black')
plt.legend()

# %% [markdown]
# #Plotting points with Grids

# %%
plt.scatter(x,y)
plt.grid(color='red')
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# #plotting piecharts

# %%
exp=[0.2,0,0.2,00.2]

plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.pie(run,labels=player,explode=exp,shadow=True,autopct='%1.1f%%')
plt.grid(color='green')
plt.show()
