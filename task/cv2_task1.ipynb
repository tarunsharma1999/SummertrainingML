# %% [markdown]
# <a href="https://colab.research.google.com/github/tarunsharma1999/SummertrainingML/blob/master/task/cv2_task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
#Two images of same dimension
image1=cv2.imread('S.jpeg')
image2=cv2.imread('img.jpg')

# %%
#replacing same part of image with third vairable
swap=np.arange(532500).reshape(355,500,3)
swap[:,0:100]=image1[0:,0:100]

image1[:,0:100]=image2[0:,0:100]
image2[:,:100]=swap[:,0:100]
cv2_imshow(image1)
cv2_imshow(image2)
# Out:
# <PIL.Image.Image image mode=RGB size=500x355 at 0x7F8264CCF4E0>
# <PIL.Image.Image image mode=RGB size=500x355 at 0x7F8264CCF390>
