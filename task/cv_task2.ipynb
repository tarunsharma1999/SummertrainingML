# %% [markdown]
# <a href="https://colab.research.google.com/github/tarunsharma1999/SummertrainingML/blob/master/task/cv_task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
image=cv2.imread('img.jpg')
image2=cv2.imread('S.jpeg')

# %%
Zoomedimg=cv2.resize(image,None,fx=1.5,fy=1.5)

# %%
cv2_imshow(image)
cv2_imshow(Zoomedimg)
# Out:
# <PIL.Image.Image image mode=RGB size=500x355 at 0x7F785DC82D30>
# <PIL.Image.Image image mode=RGB size=750x532 at 0x7F785D39A400>

# %%
Merged_img=np.concatenate((image,image2),axis=1)
cv2_imshow(Merged_img)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x355 at 0x7F785D39A400>
